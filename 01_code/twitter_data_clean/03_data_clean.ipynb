# %%
import pandas as pd

# %%
df = pd.read_csv('co-est00int-tot.csv', encoding='ISO-8859-1')

# %%
# Zero-pad the state and county codes to ensure correct lengths
df['STATE'] = df['STATE'].apply(lambda x: f'{x:02}')
df['COUNTY'] = df['COUNTY'].apply(lambda x: f'{x:03}')

# Concatenate the two columns to form the FIPS code
df['fips'] = df['STATE'] + df['COUNTY']

# %%
df.to_csv('census_county_pop.csv', index=False)

# %% [markdown]
# _____

# %%
signal = pd.read_csv('signal_final.csv')

# %%
signal['depression'] = signal.iloc[:, 5:15].sum(axis=1).apply(lambda x: 1 if x > 0 else 0)

# %%
county_depression = signal.groupby(['geoid', 'CENSUS2010POP']).agg({
    'depression': 'sum',
    'user_id': 'count'
}).reset_index()

# %%
county_depression
# Out:
#      geoid  CENSUS2010POP  depression  user_id
# 0     1003         182265           0        2
# 1     1007          22915           0        1
# 2     1015         118572           0        1
# 3     1021          43643           0        1
# 4     1033          54428           0        1
# ..     ...            ...         ...      ...
# 731  55079         947735           1       25
# 732  55101         195408           0        2
# 733  55117         115507           0        1
# 734  55127         102228           0        2
# 735  56037          43806           0        1
#
# [736 rows x 4 columns]

# %%
df_msa = pd.read_csv("https://data.nber.org/cbsa-csa-fips-county-crosswalk/cbsa2fipsxw.csv")
# Concatenate the two columns to form the FIPS code
df_msa['geoid'] = (df_msa['fipsstatecode'].apply(lambda x: f'{x:02}') + 
                   df_msa['fipscountycode'].apply(lambda x: f'{x:03}')).astype(int)
df_msa['fipscode'] = df_msa['geoid']

# %%
cbsa_depression = county_depression.merge(df_msa[['cbsatitle','cbsacode','metropolitanmicropolitanstatis','geoid']],how='left')
cbsa_depression = cbsa_depression.groupby(['cbsatitle','cbsacode','metropolitanmicropolitanstatis']).agg({
    'depression': 'sum',
    'user_id': 'sum'
}).reset_index()
cbsa_depression['depression_rate'] = cbsa_depression['depression'] / cbsa_depression['user_id'] 
cbsa_depression = cbsa_depression.loc[(cbsa_depression['depression_rate']>0) & (cbsa_depression['user_id']>= 10)]

# %%
cbsa_depression.shape
# Out:
# (91, 6)

# %%
cbsa_depression
# Out:
#                                         cbsatitle  cbsacode  \
# 1                                       Akron, OH   10420.0
# 2                                      Albany, GA   10500.0
# 4                     Albany-Schenectady-Troy, NY   10580.0
# 19              Atlanta-Sandy Springs-Roswell, GA   12060.0
# 20                    Atlantic City-Hammonton, NJ   12100.0
# ..                                            ...       ...
# 367                                  Valdosta, GA   46660.0
# 368                                   Vallejo, CA   46700.0
# 372      Virginia Beach-Chesapeake-Norfolk, VA-NC   47260.0
# 377  Washington-Arlington-Alexandria, DC-VA-MD-WV   47900.0
# 385                             Winston-Salem, NC   49180.0
#
#     metropolitanmicropolitanstatis  depression  user_id  depression_rate
# 1    Metropolitan Statistical Area           8       39         0.205128
# 2    Metropolitan Statistical Area           4       15         0.266667
# 4    Metropolitan Statistical Area           1       24         0.041667
# 19   Metropolitan Statistical Area          48      486         0.098765
# 20   Metropolitan Statistical Area           1       10         0.100000
# ..                             ...         ...      ...              ...
# 367  Metropolitan Statistical Area           4       13         0.307692
# 368  Metropolitan Statistical Area           2       17         0.117647
# 372  Metropolitan Statistical Area          27      170         0.158824
# 377  Metropolitan Statistical Area          45      401         0.112219
# 385  Metropolitan Statistical Area           3       26         0.115385
#
# [91 rows x 6 columns]

# %% [markdown]
# ---

# %%
df_pop = pd.read_csv('census_county_pop.csv')
pop_df_drop = df_pop[['CENSUS2010POP', 'fips']].copy()
pop_df_drop.columns = ['CENSUS2010POP', 'fipscode']

# %%
column_select = ['fipscode','v002_rawvalue','v037_rawvalue','v009_rawvalue','v011_rawvalue','v012_rawvalue',
                 'v045_rawvalue','v004_rawvalue','v007_rawvalue','v021_rawvalue','v022_rawvalue',
                 'v023_rawvalue','v028_rawvalue','v043_rawvalue','v041_rawvalue','v003_rawvalue']
df_factor = df_factor[column_select]
df_factor = df_factor.merge(pop_df_drop)

# %%
df_factor['v045_rawvalue'] = df_factor['v045_rawvalue']/100000 #Chlamydia cases per 100,000 people
df_factor['v004_rawvalue'] = df_factor['v004_rawvalue']/100000 #Primary care provider rate per 100,000 population
df_factor['v004_rawvalue'] = df_factor['v004_rawvalue']/100000 # Violent Crimes per 100,000 People

# %%
df_factor_cbsa = df_factor.merge(df_msa[['cbsatitle','cbsacode','metropolitanmicropolitanstatis','fipscode']],how='left')
df_factor_cbsa = df_factor_cbsa.loc[~df_factor_cbsa['cbsacode'].isna()]

# %%
# Identify all columns that follow the pattern vXXX_rawvalue
value_columns = [col for col in df_factor_cbsa.columns if col.startswith('v') and col.endswith('_rawvalue')]

# Function to calculate the weighted value for each column
def calculate_weighted(group):
    result = {}
    for col in value_columns:
        weighted_sum = (group[col].fillna(0) * group['CENSUS2010POP']).sum()
        sum_population_non_na = group.loc[group[col].notna(), 'CENSUS2010POP'].sum()
        total_population = group['CENSUS2010POP'].sum()
        
        # Calculate the desired formula
        result[col] = (weighted_sum / sum_population_non_na) * total_population if sum_population_non_na != 0 else 0
    return pd.Series(result)

# Apply the function for each group and reset index
weighted_results = df_factor_cbsa.groupby(['cbsatitle','cbsacode','metropolitanmicropolitanstatis']).apply(calculate_weighted).reset_index()

# Display the result
weighted_results
# Out:
#                  cbsatitle  cbsacode metropolitanmicropolitanstatis  \
# 0             Aberdeen, SD   10100.0  Micropolitan Statistical Area
# 1             Aberdeen, WA   10140.0  Micropolitan Statistical Area
# 2              Abilene, TX   10180.0  Metropolitan Statistical Area
# 3                  Ada, OK   10220.0  Micropolitan Statistical Area
# 4               Adrian, MI   10300.0  Micropolitan Statistical Area
# ..                     ...       ...                            ...
# 913  Youngstown-Warren, OH   49660.0  Metropolitan Statistical Area
# 914          Yuba City, CA   49700.0  Metropolitan Statistical Area
# 915               Yuma, AZ   49740.0  Metropolitan Statistical Area
# 916         Zanesville, OH   49780.0  Micropolitan Statistical Area
# 917             Zapata, TX   49820.0  Micropolitan Statistical Area
#
#      v002_rawvalue  v037_rawvalue  v009_rawvalue  v011_rawvalue  \
# 0      5322.000000      2241.2304      8028.9180      11202.081
# 1     12812.272000      4258.6245     19487.7569      24605.386
# 2     37786.460799     13953.0436     40453.6896      44800.770
# 3      8506.934800      2999.3600     10977.6576      11697.504
# 4     12426.564800      6912.5264     18470.0308      30167.384
# ..             ...            ...            ...            ...
# 913   72038.772300     40846.2945    109967.2016     125786.311
# 914   27770.828800     10432.4062         0.0000      42981.035
# 915   39091.474700     11353.5580     30752.4821      50308.007
# 916   11284.301400      7763.8748     26097.6368      25908.274
# 917       0.000000      1076.5824         0.0000       3756.824
#
#      v012_rawvalue  v045_rawvalue  v004_rawvalue  v007_rawvalue  \
# 0       7691.88150     103.230333       0.000303     36724.7973
# 1      10766.67630     130.161036       0.000311     62707.3358
# 2      17573.04852     656.176240       0.001116    124688.1388
# 3       5140.15320     149.555588       0.000286     24770.9644
# 4      16721.92080     144.643616       0.000426     85517.5412
# ..             ...            ...            ...            ...
# 913    70835.03050    1437.548274       0.003886    358715.4324
# 914    26869.61200     435.044654       0.001155    128658.7414
# 915    33375.54550     516.586889       0.000967    159204.2883
# 916     8968.91080     227.837878       0.000506     71716.8568
# 917        0.00000      23.676402       0.000053     10160.2464
#
#      v021_rawvalue  v022_rawvalue  v023_rawvalue  v028_rawvalue  \
# 0     35098.231049    9251.634420        986.661    2740.168455
# 1     52314.689962    9270.989153       5605.369    8273.696321
# 2    125011.108850   32853.874583       6508.456   15368.343648
# 3     31555.088936    9200.490797       1199.744    3314.825659
# 4     82252.597671   18507.848103      10188.984    9225.036529
# ..             ...            ...            ...            ...
# 913  358226.929339   79763.210499      32729.833   45195.615530
# 914  117705.517795   25321.597134      20311.251   18279.954689
# 915       0.000000   24493.789757      33473.421   20727.312271
# 916   71871.076283   10988.912044       7402.364    9326.344481
# 917    9728.008620    1217.113607        785.008    1308.489671
#
#      v043_rawvalue  v041_rawvalue  v003_rawvalue
# 0     0.000000e+00   41583.261650       4756.017
# 1     1.364215e+07   51384.183180      10045.986
# 2     7.031154e+07  124815.404703      36100.208
# 3     1.837417e+07   20907.874191       7310.940
# 4     2.187368e+07   49270.015393      10688.444
# ..             ...            ...            ...
# 913   0.000000e+00  332987.543627      51832.326
# 914   7.593015e+07  114381.071179      31141.595
# 915   0.000000e+00   73732.760808      38562.947
# 916   0.000000e+00   70469.941521       9382.066
# 917   3.327694e+06       0.000000       4822.192
#
# [918 rows x 18 columns]

# %%
pop_cbsa = df_factor_cbsa.groupby(['cbsatitle','cbsacode','metropolitanmicropolitanstatis']).agg({'CENSUS2010POP':'sum'}).reset_index()

# %% [markdown]
# ---

# %%
cbsa_depression.merge(weighted_results,how='left').merge(pop_cbsa,how='left').to_csv('tweet2020_analysis.csv', index=False)
