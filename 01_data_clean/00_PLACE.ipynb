# %%
import pandas as pd

# %%
# https://chronicdata.cdc.gov/500-Cities-Places/PLACES-Local-Data-for-Better-Health-County-Data-20/swc5-untb/about_data
# https://www.cdc.gov/places/measure-definitions/index.html
df = pd.read_csv('../00_data/01_raw/PLACES__Local_Data_for_Better_Health,_County_Data_2024_release_20250828.csv',low_memory=False)

# %%
df['Short_Question_Text'].unique()
# Out:
# array(['Current Asthma', 'Arthritis', 'Stroke', 'Obesity',
#        'Any Disability', 'Binge Drinking', 'High Blood Pressure',
#        'Diabetes', 'Depression', 'Cognitive Disability',
#        'Frequent Mental Distress', 'All Teeth Lost', 'Hearing Disability',
#        'COPD', 'Vision Disability', 'Mobility Disability', 'Mammography',
#        'Self-care Disability', 'Cholesterol Screening',
#        'Coronary Heart Disease', 'Food Insecurity',
#        'Independent Living Disability', 'Physical Inactivity',
#        'Utility Services Threat', 'High Cholesterol',
#        'Current Cigarette Smoking', 'Short Sleep Duration',
#        'Health Insurance', 'Frequent Physical Distress', 'General Health',
#        'Annual Checkup', 'Colorectal Cancer Screening', 'Dental Visit',
#        'Social Isolation', 'Food Stamps',
#        'High Blood Pressure Medication',
#        'Lack of Social/Emotional Support', 'Housing Insecurity',
#        'Cancer (non-skin) or Melanoma', 'Transportation Barriers'],
#       dtype=object)

# %%
df.loc[df['Short_Question_Text']=='Any Disability']
# Out:
#         Year StateAbbr   StateDesc LocationName DataSource    Category  \
# 4       2022        AL     Alabama     Lawrence      BRFSS  Disability
# 20      2022        AR    Arkansas        Cross      BRFSS  Disability
# 54      2022        AL     Alabama    Covington      BRFSS  Disability
# 77      2022        AR    Arkansas        Perry      BRFSS  Disability
# 80      2022        CA  California         Inyo      BRFSS  Disability
# ...      ...       ...         ...          ...        ...         ...
# 240731  2022        WY     Wyoming       Albany      BRFSS  Disability
# 240754  2022        WI   Wisconsin    Jefferson      BRFSS  Disability
# 240797  2022        WI   Wisconsin     Walworth      BRFSS  Disability
# 240838  2022        WY     Wyoming   Sweetwater      BRFSS  Disability
# 240872  2022        WI   Wisconsin      Kenosha      BRFSS  Disability
#
#                             Measure Data_Value_Unit          Data_Value_Type  \
# 4       Any disability among adults               %         Crude prevalence
# 20      Any disability among adults               %         Crude prevalence
# 54      Any disability among adults               %         Crude prevalence
# 77      Any disability among adults               %         Crude prevalence
# 80      Any disability among adults               %  Age-adjusted prevalence
# ...                             ...             ...                      ...
# 240731  Any disability among adults               %  Age-adjusted prevalence
# 240754  Any disability among adults               %  Age-adjusted prevalence
# 240797  Any disability among adults               %         Crude prevalence
# 240838  Any disability among adults               %         Crude prevalence
# 240872  Any disability among adults               %         Crude prevalence
#
#         Data_Value  ... Low_Confidence_Limit High_Confidence_Limit  \
# 4             40.1  ...                 35.5                  44.7
# 20            41.9  ...                 37.3                  46.4
# 54            36.3  ...                 32.0                  40.7
# 77            40.5  ...                 35.8                  45.4
# 80            28.3  ...                 24.4                  32.4
# ...            ...  ...                  ...                   ...
# 240731        28.9  ...                 25.2                  32.7
# 240754        28.0  ...                 24.1                  32.2
# 240797        27.0  ...                 23.6                  30.8
# 240838        31.1  ...                 27.2                  35.0
# 240872        33.3  ...                 29.8                  37.0
#
#         TotalPopulation  TotalPop18plus LocationID CategoryID   MeasureId  \
# 4                33,214          26,022       1079    DISABLT  DISABILITY
# 20               16,601          12,703       5037    DISABLT  DISABILITY
# 54               37,602          29,340       1039    DISABLT  DISABILITY
# 77               10,063           7,925       5105    DISABLT  DISABILITY
# 80               18,718          14,942       6027    DISABLT  DISABILITY
# ...                 ...             ...        ...        ...         ...
# 240731           38,031          32,250      56001    DISABLT  DISABILITY
# 240754           85,784          69,136      55055    DISABLT  DISABILITY
# 240797          105,380          85,160      55127    DISABLT  DISABILITY
# 240838           41,345          31,117      56037    DISABLT  DISABILITY
# 240872          167,817         131,730      55059    DISABLT  DISABILITY
#
#        DataValueTypeID Short_Question_Text  \
# 4               CrdPrv      Any Disability
# 20              CrdPrv      Any Disability
# 54              CrdPrv      Any Disability
# 77              CrdPrv      Any Disability
# 80           AgeAdjPrv      Any Disability
# ...                ...                 ...
# 240731       AgeAdjPrv      Any Disability
# 240754       AgeAdjPrv      Any Disability
# 240797          CrdPrv      Any Disability
# 240838          CrdPrv      Any Disability
# 240872          CrdPrv      Any Disability
#
#                                        Geolocation
# 4       POINT (-87.3108851040374 34.5216735395968)
# 20      POINT (-90.7714945147511 35.2958747021642)
# 54       POINT (-86.451444907521 31.2486200676573)
# 77      POINT (-92.9308792596259 34.9473919842415)
# 80      POINT (-117.411112581295 36.5114226868129)
# ...                                            ...
# 240731  POINT (-105.723439465307 41.6544509650776)
# 240754  POINT (-88.7759315522696 43.0208620651204)
# 240797  POINT (-88.5418387513161 42.6685116518019)
# 240838  POINT (-108.879886957441 41.6596981373813)
# 240872  POINT (-88.0420010334725 42.5767151176665)
#
# [6290 rows x 22 columns]

# %%
factor_list = [
       'DEPRESSION', #
       'DIABETES', #
       'OBESITY', #
       # 23% Missing 'ISOLATION', # adults who report always/usually/sometimes feeling socially isolated.
       # 23% Missing 'EMOTIONSPT', # adults who report sometimes, rarely, or never getting the social and emotional support needed.
       'BINGE', # adults who report having ≥5 drinks (men) or ≥4 drinks (women) on ≥1 occasion during the previous 30 days.
       'CSMOKING', # adults who report having smoked ≥ 100 cigarettes in their lifetime and currently smoke every day or some days.
       'LPA', # having no leisure-time physical activity 
       'CANCER',
       'VISION', #Vision Disability
       'MOBILITY',
       'SELFCARE',
       'DISABILITY'
]

# %%
df_select = df.loc[(df['MeasureId'].isin(factor_list)) & (df['DataValueTypeID'] == 'CrdPrv')].copy()
df_select['TotalPopulation'] = df['TotalPopulation'].str.replace(',', '').astype('int')
df_select['Value_N'] = df_select['TotalPopulation'] * df_select['Data_Value'] * 0.01

# %%
df_clean = df_select.pivot(index=['StateAbbr','LocationName','LocationID','TotalPopulation'],
                columns='MeasureId',
                values='Value_N').reset_index().dropna()

# %%
df_clean.to_csv('../00_data/02_intermediate/place.csv',index=False)
